# %% [markdown]
# ## *BHARAT INTERN DATA SCIENCE INTERNSHIP*
# 1.        **STOCK PREDICTION**
# 2.          **NAME : KAVINRAJ T**

# %% [markdown]
# **STEP 1 IMPORTING LIBRARIES AND DATA TO BE USED**

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/Task_1_Stocks_dataset.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# ** *italicized text*STEP 2 GATHERING INSIGHTS**

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# **THERE ARE NO NULL VALUES IN THE
#
# 1.   List item
# 2.   List item
#
# DATASET**

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# **STEP 3 DATA PRE-PROCESSING**

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]
train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e58353a382d2> in <cell line: 1>()
# ----> 1 train_seq, train_label = create_sequence(train_data)
#       2 test_seq, test_label = create_sequence(test_data)
#       3 train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
#
# NameError: name 'create_sequence' is not defined

# %% [markdown]
# **STEP 4 :  CREATING LSTM MODEL**

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 118ms/step - loss: 0.0107 - mean_absolute_error: 0.0716 - val_loss: 0.0193 - val_mean_absolute_error: 0.1162
# Epoch 2/100
# 28/28 [==============================] - 3s 100ms/step - loss: 0.0011 - mean_absolute_error: 0.0273 - val_loss: 0.0076 - val_mean_absolute_error: 0.0709
# Epoch 3/100
# 28/28 [==============================] - 2s 74ms/step - loss: 4.9401e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355
# Epoch 4/100
# 28/28 [==============================] - 2s 54ms/step - loss: 4.6648e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0030 - val_mean_absolute_error: 0.0420
# Epoch 5/100
# 28/28 [==============================] - 2s 54ms/step - loss: 4.4211e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0047 - val_mean_absolute_error: 0.0550
# Epoch 6/100
# 28/28 [==============================] - 2s 59ms/step - loss: 4.3833e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0038 - val_mean_absolute_error: 0.0479
# Epoch 7/100
# 28/28 [==============================] - 1s 53ms/step - loss: 4.3422e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0041 - val_mean_absolute_error: 0.0500
# Epoch 8/100
# 28/28 [==============================] - 2s 61ms/step - loss: 4.1487e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0038 - val_mean_absolute_error: 0.0480
# Epoch 9/100
# 28/28 [==============================] - 2s 64ms/step - loss: 4.0010e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 10/100
# 28/28 [==============================] - 3s 96ms/step - loss: 3.9110e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0046 - val_mean_absolute_error: 0.0531
# Epoch 11/100
# 28/28 [==============================] - 2s 86ms/step - loss: 3.7983e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0062 - val_mean_absolute_error: 0.0641
# Epoch 12/100
# 28/28 [==============================] - 2s 85ms/step - loss: 3.5299e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0049 - val_mean_absolute_error: 0.0558
# Epoch 13/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.6370e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0063 - val_mean_absolute_error: 0.0643
# Epoch 14/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.6572e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0039 - val_mean_absolute_error: 0.0472
# Epoch 15/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.7960e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0080 - val_mean_absolute_error: 0.0732
# Epoch 16/100
# 28/28 [==============================] - 2s 59ms/step - loss: 3.4686e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0052 - val_mean_absolute_error: 0.0564
# Epoch 17/100
# 28/28 [==============================] - 3s 94ms/step - loss: 3.3080e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0054 - val_mean_absolute_error: 0.0569
# Epoch 18/100
# 28/28 [==============================] - 3s 90ms/step - loss: 3.2231e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0042 - val_mean_absolute_error: 0.0484
# Epoch 19/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.4929e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0092 - val_mean_absolute_error: 0.0783
# Epoch 20/100
# 28/28 [==============================] - 3s 107ms/step - loss: 3.2456e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0068 - val_mean_absolute_error: 0.0656
# Epoch 21/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.2828e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0069 - val_mean_absolute_error: 0.0659
# Epoch 22/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.0640e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0059 - val_mean_absolute_error: 0.0600
# Epoch 23/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.1056e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0066 - val_mean_absolute_error: 0.0643
# Epoch 24/100
# 28/28 [==============================] - 3s 121ms/step - loss: 2.7277e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0064 - val_mean_absolute_error: 0.0627
# Epoch 25/100
# 28/28 [==============================] - 3s 118ms/step - loss: 2.9792e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0072 - val_mean_absolute_error: 0.0675
# Epoch 26/100
# 28/28 [==============================] - 2s 85ms/step - loss: 2.8618e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0050 - val_mean_absolute_error: 0.0554
# Epoch 27/100
# 28/28 [==============================] - 4s 127ms/step - loss: 2.8020e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0036 - val_mean_absolute_error: 0.0448
# Epoch 28/100
# 28/28 [==============================] - 4s 141ms/step - loss: 2.5715e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0060 - val_mean_absolute_error: 0.0603
# Epoch 29/100
# 28/28 [==============================] - 4s 132ms/step - loss: 2.5675e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0072 - val_mean_absolute_error: 0.0675
# Epoch 30/100
# 28/28 [==============================] - 2s 80ms/step - loss: 2.5624e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0044 - val_mean_absolute_error: 0.0500
# Epoch 31/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.5890e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0069 - val_mean_absolute_error: 0.0666
# Epoch 32/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.5176e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0026 - val_mean_absolute_error: 0.0369
# Epoch 33/100
# 28/28 [==============================] - 1s 54ms/step - loss: 3.0009e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0047 - val_mean_absolute_error: 0.0528
# Epoch 34/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.8199e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0057 - val_mean_absolute_error: 0.0609
# Epoch 35/100
# 28/28 [==============================] - 2s 74ms/step - loss: 2.8175e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0047 - val_mean_absolute_error: 0.0531
# Epoch 36/100
# 28/28 [==============================] - 3s 91ms/step - loss: 2.5807e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0033 - val_mean_absolute_error: 0.0430
# Epoch 37/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.6114e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0042 - val_mean_absolute_error: 0.0493
# Epoch 38/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2529e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0028 - val_mean_absolute_error: 0.0385
# Epoch 39/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.3741e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0046 - val_mean_absolute_error: 0.0524
# Epoch 40/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.2195e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0057 - val_mean_absolute_error: 0.0597
# Epoch 41/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.2784e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0035 - val_mean_absolute_error: 0.0446
# Epoch 42/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.0813e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0035 - val_mean_absolute_error: 0.0442
# Epoch 43/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.1023e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0042 - val_mean_absolute_error: 0.0494
# Epoch 44/100
# 28/28 [==============================] - 3s 111ms/step - loss: 2.0592e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0022 - val_mean_absolute_error: 0.0335
# Epoch 45/100
# 28/28 [==============================] - 2s 84ms/step - loss: 2.2675e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0034 - val_mean_absolute_error: 0.0441
# Epoch 46/100
# 28/28 [==============================] - 3s 98ms/step - loss: 2.0111e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0030 - val_mean_absolute_error: 0.0408
# Epoch 47/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.0443e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0020 - val_mean_absolute_error: 0.0321
# Epoch 48/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.0257e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0035 - val_mean_absolute_error: 0.0445
# Epoch 49/100
# 28/28 [==============================] - 4s 136ms/step - loss: 1.9819e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0056 - val_mean_absolute_error: 0.0603
# Epoch 50/100
# 28/28 [==============================] - 5s 187ms/step - loss: 1.9624e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0042 - val_mean_absolute_error: 0.0499
# Epoch 51/100
# 28/28 [==============================] - 3s 92ms/step - loss: 1.8650e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0027 - val_mean_absolute_error: 0.0394
# Epoch 52/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.9871e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269
# Epoch 53/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.9205e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0045 - val_mean_absolute_error: 0.0536
# Epoch 54/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.8086e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0040 - val_mean_absolute_error: 0.0504
# Epoch 55/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.9176e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0028 - val_mean_absolute_error: 0.0396
# Epoch 56/100
# 28/28 [==============================] - 3s 106ms/step - loss: 1.7444e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0018 - val_mean_absolute_error: 0.0312
# Epoch 57/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.9402e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0037 - val_mean_absolute_error: 0.0470
# Epoch 58/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.6490e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0046 - val_mean_absolute_error: 0.0534
# Epoch 59/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.6784e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0047 - val_mean_absolute_error: 0.0564
# Epoch 60/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.6937e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0020 - val_mean_absolute_error: 0.0331
# Epoch 61/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.7290e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
# Epoch 62/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7146e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0022 - val_mean_absolute_error: 0.0365
# Epoch 63/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.6062e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0023 - val_mean_absolute_error: 0.0363
# Epoch 64/100
# 28/28 [==============================] - 3s 94ms/step - loss: 1.5453e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0020 - val_mean_absolute_error: 0.0331
# Epoch 65/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.6723e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280
# Epoch 66/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.4907e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 67/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.6023e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0021 - val_mean_absolute_error: 0.0348
# Epoch 68/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.4617e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0019 - val_mean_absolute_error: 0.0328
# Epoch 69/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.3600e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0028 - val_mean_absolute_error: 0.0423
# Epoch 70/100
# 28/28 [==============================] - 3s 97ms/step - loss: 1.5484e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 71/100
# 28/28 [==============================] - 5s 163ms/step - loss: 1.7073e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0015 - val_mean_absolute_error: 0.0290
# Epoch 72/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.4447e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0019 - val_mean_absolute_error: 0.0336
# Epoch 73/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.4914e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 74/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.5779e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 75/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.4185e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0017 - val_mean_absolute_error: 0.0322
# Epoch 76/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.3385e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0023 - val_mean_absolute_error: 0.0393
# Epoch 77/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.4266e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0021 - val_mean_absolute_error: 0.0372
# Epoch 78/100
# 28/28 [==============================] - 4s 129ms/step - loss: 1.6080e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0020 - val_mean_absolute_error: 0.0356
# Epoch 79/100
# 28/28 [==============================] - 4s 129ms/step - loss: 1.3241e-04 - mean_absolute_error: 0.0083 - val_loss: 9.2606e-04 - val_mean_absolute_error: 0.0228
# Epoch 80/100
# 28/28 [==============================] - 3s 106ms/step - loss: 1.5249e-04 - mean_absolute_error: 0.0089 - val_loss: 9.8362e-04 - val_mean_absolute_error: 0.0238
# Epoch 81/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.4293e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0016 - val_mean_absolute_error: 0.0323
# Epoch 82/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.5655e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0035 - val_mean_absolute_error: 0.0494
# Epoch 83/100
# 28/28 [==============================] - 3s 96ms/step - loss: 1.4362e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0016 - val_mean_absolute_error: 0.0308
# Epoch 84/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.4088e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0013 - val_mean_absolute_error: 0.0283
# Epoch 85/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.1960e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 86/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1101e-04 - mean_absolute_error: 0.0076 - val_loss: 7.7713e-04 - val_mean_absolute_error: 0.0216
# Epoch 87/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3237e-04 - mean_absolute_error: 0.0083 - val_loss: 5.2104e-04 - val_mean_absolute_error: 0.0170
# Epoch 88/100
# 28/28 [==============================] - 3s 91ms/step - loss: 1.1922e-04 - mean_absolute_error: 0.0078 - val_loss: 4.0104e-04 - val_mean_absolute_error: 0.0149
# Epoch 89/100
# 28/28 [==============================] - 4s 136ms/step - loss: 1.2688e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 90/100
# 28/28 [==============================] - 4s 125ms/step - loss: 1.2004e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0017 - val_mean_absolute_error: 0.0352
# Epoch 91/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3073e-04 - mean_absolute_error: 0.0083 - val_loss: 5.8294e-04 - val_mean_absolute_error: 0.0186
# Epoch 92/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1209e-04 - mean_absolute_error: 0.0076 - val_loss: 7.7607e-04 - val_mean_absolute_error: 0.0220
# Epoch 93/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.2059e-04 - mean_absolute_error: 0.0080 - val_loss: 4.1617e-04 - val_mean_absolute_error: 0.0152
# Epoch 94/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.1514e-04 - mean_absolute_error: 0.0077 - val_loss: 8.9823e-04 - val_mean_absolute_error: 0.0236
# Epoch 95/100
# 28/28 [==============================] - 2s 76ms/step - loss: 1.1513e-04 - mean_absolute_error: 0.0076 - val_loss: 9.6211e-04 - val_mean_absolute_error: 0.0240
# Epoch 96/100
# 28/28 [==============================] - 4s 139ms/step - loss: 1.1447e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0012 - val_mean_absolute_error: 0.0284
# Epoch 97/100
# 28/28 [==============================] - 3s 121ms/step - loss: 1.1690e-04 - mean_absolute_error: 0.0077 - val_loss: 5.5101e-04 - val_mean_absolute_error: 0.0179
# Epoch 98/100
# 28/28 [==============================] - 4s 136ms/step - loss: 1.0982e-04 - mean_absolute_error: 0.0075 - val_loss: 3.4010e-04 - val_mean_absolute_error: 0.0136
# Epoch 99/100
# 28/28 [==============================] - 4s 136ms/step - loss: 1.1240e-04 - mean_absolute_error: 0.0075 - val_loss: 4.7505e-04 - val_mean_absolute_error: 0.0164
# Epoch 100/100
# 28/28 [==============================] - 4s 145ms/step - loss: 1.2394e-04 - mean_absolute_error: 0.0080 - val_loss: 6.4583e-04 - val_mean_absolute_error: 0.0200

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 15ms/step
# array([[0.40305665, 0.40086037],
#        [0.4019343 , 0.39980945],
#        [0.39640135, 0.39445734],
#        [0.40074125, 0.39874804],
#        [0.40455255, 0.40252966]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1418.2347, 1411.1906],
#        [1416.1539, 1409.2428],
#        [1405.8964, 1399.3236],
#        [1413.9421, 1407.2758],
#        [1421.008 , 1414.2843]], dtype=float32)

# %% [markdown]
#  **STEP 5 :  VISUALIZING ACTUAL VS PREDICTED DATA**

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1418.234741      1411.190552
# 2020-05-28  1396.86  1416.73     1416.153931      1409.242798
# 2020-05-29  1416.94  1428.92     1405.896362      1399.323608
# 2020-06-01  1418.39  1431.82     1413.942139      1407.275757
# 2020-06-02  1430.55  1439.22     1421.008057      1414.284302

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# **STEP 6. PREDICTING UPCOMING 10 DAYS**

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2435.556885      2446.714844
# 2021-06-10  2494.01  2521.60     2445.188721      2456.305908
# 2021-06-11  2524.92  2513.93     2458.792480      2469.779541
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# **Thank you**
